# %% [markdown]
# # 🐶Distributions

# %%
# Descargar
# ] add Distributions

# %%
using Distributions
using Plots
using StatsPlots

# %%
## crear observaciones pseudoaleatorias que provengan de una variable aleatoria Normal

x = rand(Normal(), 1000);
histogram(x, normalize = true, label = "Obs", c = :blue4)
plot!(Normal(), lw = 3, label = "Teoric", c = :orange)

# %%
mean(Normal())
# Out:
# 0.0

# %%
mean(x)
# Out:
# 0.0123558722171049

# %%
var(Normal())
# Out:
# 1.0

# %%
var(x)
# Out:
# 1.050823908664585

# %%
std(x)
# Out:
# 1.0250970240248407

# %%
fit(Normal,x)
# Out:
# Normal{Float64}(μ=0.01235587221710491, σ=1.0245843473115912)

# %%
y = rand(Beta(4, 15), 1000);

# %%
histogram(y, normalize = true)
plot!(Beta(4,15))

# %%
fit(Beta, y)
# Out:
# Beta{Float64}(α=4.226513363217871, β=16.426464487932897)

# %%
scatter(x, y, label = "Obs", alpha = 0.8, c = :tomato)

# %%
fieldnames(Normal)
# Out:
# (:μ, :σ)
