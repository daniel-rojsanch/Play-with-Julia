# %%
using Plots
using DataFrames
using RDatasets

# %%
data = dataset("datasets","cars");

# %%
describe(data)
# Out:
# 2×7 DataFrame
#  Row │ variable  mean     min    median   max    nmissing  eltype
#      │ Symbol    Float64  Int64  Float64  Int64  Int64     DataType
# ─────┼──────────────────────────────────────────────────────────────
#    1 │ Speed       15.4       4     15.0     25         0  Int64
#    2 │ Dist        42.98      2     36.0    120         0  Int64

# %%
scatter(data.Speed, data.Dist)

# %%
histogram(data.Speed, bins = 10)

# %%
data2 = dataset("datasets", "mtcars")
data2[1:5,:]
# Out:
# 5×12 DataFrame
#  Row │ Model              MPG      Cyl    Disp     HP     DRat     WT       QS ⋯
#      │ String31           Float64  Int64  Float64  Int64  Float64  Float64  Fl ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Mazda RX4             21.0      6    160.0    110     3.9     2.62      ⋯
#    2 │ Mazda RX4 Wag         21.0      6    160.0    110     3.9     2.875
#    3 │ Datsun 710            22.8      4    108.0     93     3.85    2.32
#    4 │ Hornet 4 Drive        21.4      6    258.0    110     3.08    3.215
#    5 │ Hornet Sportabout     18.7      8    360.0    175     3.15    3.44      ⋯
#                                                                5 columns omitted

# %%
p1 = scatter(data2[:,:MPG], data2[:,:Disp])

# %%
bar(data2.Model, data2.MPG, bar_width = 0.1, color = :pink, xrotation=45, size = (1000, 800))
